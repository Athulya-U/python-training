# %% [markdown]
# <a href="https://colab.research.google.com/github/Athulya-U/python-training/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("Enter the number of elements:"))
lst=[]
for i in range(n):
  lst.append(input("enter element:"))
  print("list:",lst)
# Out:
# Enter the number of elements:2
# enter element:4
# list: ['4']
# enter element:2
# list: ['4', '2']

# %%
n=int(input("enter number of elements"))
l=[]
for i in range(n):
  m=int(input("enter the element"))
  l.append(m)
  print(l)
  print("the largest element is",max(l))
# Out:
# enter number of elements4
# enter the element5
# [5]
# the largest element is 5
# enter the element6
# [5, 6]
# the largest element is 6
# enter the element2
# [5, 6, 2]
# the largest element is 6
# enter the element9
# [5, 6, 2, 9]
# the largest element is 9

# %%
n=int(input("enter number of elements"))
l=[]
for i in range(n):
  m=int(input("enter the element"))
  l.append(m)
  print(l)
  print("the smallest element is",min(l))
# Out:
# enter number of elements4
# enter the element5
# [5]
# the smallest element is 5
# enter the element2
# [5, 2]
# the smallest element is 2
# enter the element7
# [5, 2, 7]
# the smallest element is 2
# enter the element1
# [5, 2, 7, 1]
# the smallest element is 1

# %%
n=int(input("Enter the number of elements"))
sum=0
for i in range(n):
  l=int(input("Enter the element"))
  sum=sum+l
  print("The sum of elements is",sum)
# Out:
# Enter the number of elements4
# Enter the element2
# The sum of elements is 2
# Enter the element3
# The sum of elements is 5
# Enter the element4
# The sum of elements is 9
# Enter the element7
# The sum of elements is 16

# %%
l=[]
n=int(input("Enter the number of elements:"))
for i in range(n):
  l.append(int(input("enter the elements:")))
  print(l)
  print("Reversed:",l[::-1])
# Out:
# Enter the number of elements:3
# enter the elements:45
# [45]
# Reversed: [45]
# enter the elements:34
# [45, 34]
# Reversed: [34, 45]
# enter the elements:12
# [45, 34, 12]
# Reversed: [12, 34, 45]

# %%
list=[]
n=int(input("Enter the number of elements:"))
for i in range(n):
  a=int(input("Enter element:"))
  list.append(a)
  a=int(input("Enter the element to be searched"))
  if a in list:
    print("Element exist")
  else:
      print("Element does not exist")
# Out:
# Enter the number of elements:5
# Enter element:10
# Enter the element to be searched20
# Element does not exist
# Enter element:30
# Enter the element to be searched40
# Element does not exist
# Enter element:50
# Enter the element to be searched30
# Element exist
# Enter element:25
# Enter the element to be searched20
# Element does not exist
# Enter element:10
# Enter the element to be searched45
# Element does not exist

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("Enter the elements:"))
  list.append(b)
  el=int(input("enter element to be checked:"))
  count=list.count(el)
  print("Occurance of",el,"is:",count)
# Out:
# Enter the list size:5
# Enter the elements:10
# enter element to be checked:20
# Occurance of 20 is: 0
# Enter the elements:10
# enter element to be checked:30
# Occurance of 30 is: 0
# Enter the elements:20
# enter element to be checked:10
# Occurance of 10 is: 2
# Enter the elements:10
# enter element to be checked:2
# Occurance of 2 is: 0
# Enter the elements:30
# enter element to be checked:30
# Occurance of 30 is: 1

# %%
list=[]
n=int(input("Enter the number of elements:"))
for i in range(n):
 list.append(int(input("Enter element:")))
list.sort()
print("second largest",list[-2])
# Out:
# Enter the number of elements:5
# Enter element:10
# Enter element:25
# Enter element:7
# Enter element:30
# Enter element:15
# second largest 25
